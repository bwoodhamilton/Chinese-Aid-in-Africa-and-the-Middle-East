# %% [markdown]
# # NLP Modeling to Predict Chinese Project Financing
#
# ### Since the Chinese government is not transparent in its aid contributions, the data from William and Mary's Aid Data project is missing a lot of project funding amounts. The text columns do have a lot of descriptive text columns, so I thought it would be interesting to see how well NLP modeling would predict the amount contributed to projects.

# %%
# Importing libraries needed for modeling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import stop_words
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

# %%
# Reading in cleaned Chinese data
china_aid = pd.read_csv('./aid_data/aid_data_wm/chinese_official_finance_clean.csv')

# %%
# Looking at the dataframe I read in 
china_aid.head()
# Out:
#   all_recipients        crs_sector_name                                flow  \
# 0     Mauritania                 Health  Free-standing technical assistance
# 1     Mauritania                 Health  Free-standing technical assistance
# 2     Mauritania                 Health  Free-standing technical assistance
# 3     Mauritania                 Health  Free-standing technical assistance
# 4     Mauritania  Transport and Storage  Loan (excluding debt rescheduling)
#
#   flow_class                                     funding_agency       intent  \
# 0   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 1   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 2   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 3   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 4   ODA-like     Export-Import Bank of China, Government Agency  Development
#
#   location_details  latitude  longitude  place_name  usd_defl_2014  year  \
# 0          unknown  18.08581  -15.97850  Nouakchott            NaN  2010
# 1          unknown  15.15846  -12.18430   Sélibaby            NaN  2010
# 2          unknown  16.61659  -11.40453       Kiffa            NaN  2010
# 3          unknown   0.00000    0.00000  Mauritania            NaN  2010
# 4       Nouakchott  18.08581  -15.97850  Nouakchott    396886331.0  2008
#
#                                        project_title recipient_condensed  \
# 0  29th medical team to Mauritania to assist loca...          Mauritania
# 1  29th medical team to Mauritania to assist loca...          Mauritania
# 2  29th medical team to Mauritania to assist loca...          Mauritania
# 3  29th medical team to Mauritania to assist loca...          Mauritania
# 4  China issues 2 billion yuan loan to fund Port ...          Mauritania
#
#      round_coded  null_amounts_as_zero
# 0  ChinatoAfrica                   0.0
# 1  ChinatoAfrica                   0.0
# 2  ChinatoAfrica                   0.0
# 3  ChinatoAfrica                   0.0
# 4  ChinatoAfrica           396886331.0

# %%
# Creating one column with all the text into one column 
china_aid['words'] = china_aid['funding_agency'] + ' ' + china_aid['all_recipients'] + ' ' + china_aid['crs_sector_name'] + ' ' + china_aid['flow'] + ' ' + china_aid['flow_class'] + ' ' + china_aid['intent'] + ' ' + china_aid['location_details'] + ' ' + china_aid['place_name'] + ' ' + china_aid['project_title'] + ' ' + china_aid['recipient_condensed'] + ' ' + china_aid['round_coded']

# %%
# Checking to see how my dataframe looks 
china_aid.head()
# Out:
#   all_recipients        crs_sector_name                                flow  \
# 0     Mauritania                 Health  Free-standing technical assistance
# 1     Mauritania                 Health  Free-standing technical assistance
# 2     Mauritania                 Health  Free-standing technical assistance
# 3     Mauritania                 Health  Free-standing technical assistance
# 4     Mauritania  Transport and Storage  Loan (excluding debt rescheduling)
#
#   flow_class                                     funding_agency       intent  \
# 0   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 1   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 2   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 3   ODA-like  Unspecified Chinese Government Institution, Go...  Development
# 4   ODA-like     Export-Import Bank of China, Government Agency  Development
#
#   location_details  latitude  longitude  place_name  usd_defl_2014  year  \
# 0          unknown  18.08581  -15.97850  Nouakchott            NaN  2010
# 1          unknown  15.15846  -12.18430   Sélibaby            NaN  2010
# 2          unknown  16.61659  -11.40453       Kiffa            NaN  2010
# 3          unknown   0.00000    0.00000  Mauritania            NaN  2010
# 4       Nouakchott  18.08581  -15.97850  Nouakchott    396886331.0  2008
#
#                                        project_title recipient_condensed  \
# 0  29th medical team to Mauritania to assist loca...          Mauritania
# 1  29th medical team to Mauritania to assist loca...          Mauritania
# 2  29th medical team to Mauritania to assist loca...          Mauritania
# 3  29th medical team to Mauritania to assist loca...          Mauritania
# 4  China issues 2 billion yuan loan to fund Port ...          Mauritania
#
#      round_coded  null_amounts_as_zero  \
# 0  ChinatoAfrica                   0.0
# 1  ChinatoAfrica                   0.0
# 2  ChinatoAfrica                   0.0
# 3  ChinatoAfrica                   0.0
# 4  ChinatoAfrica           396886331.0
#
#                                                words
# 0  Unspecified Chinese Government Institution, Go...
# 1  Unspecified Chinese Government Institution, Go...
# 2  Unspecified Chinese Government Institution, Go...
# 3  Unspecified Chinese Government Institution, Go...
# 4  Export-Import Bank of China, Government Agency...

# %%
# Looking at the info for missing values and data types 
china_aid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3644 entries, 0 to 3643
# Data columns (total 17 columns):
# all_recipients          3644 non-null object
# crs_sector_name         3644 non-null object
# flow                    3644 non-null object
# flow_class              3644 non-null object
# funding_agency          3644 non-null object
# intent                  3644 non-null object
# location_details        3644 non-null object
# latitude                3644 non-null float64
# longitude               3644 non-null float64
# place_name              3644 non-null object
# usd_defl_2014           2208 non-null float64
# year                    3644 non-null int64
# project_title           3644 non-null object
# recipient_condensed     3644 non-null object
# round_coded             3644 non-null object
# null_amounts_as_zero    3644 non-null float64
# words                   3644 non-null object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 484.1+ KB

# %%
# Creating a data frame with known values for modeling 
china_aid_known = china_aid[china_aid['null_amounts_as_zero'] != 0]

# %%
# Creating a dataframe with all the unknown values
china_aid_unknown = china_aid[china_aid['null_amounts_as_zero'] == 0.0]

# %%
# Looking at the shape of my unknown values
china_aid_unknown.shape
# Out:
# (1436, 17)

# %%
# Looking at my unknown aid dataframe 
china_aid_unknown.head()
# Out:
#   all_recipients               crs_sector_name  \
# 0     Mauritania                        Health
# 1     Mauritania                        Health
# 2     Mauritania                        Health
# 3     Mauritania                        Health
# 6         Angola  Government and Civil Society
#
#                                  flow flow_class  \
# 0  Free-standing technical assistance   ODA-like
# 1  Free-standing technical assistance   ODA-like
# 2  Free-standing technical assistance   ODA-like
# 3  Free-standing technical assistance   ODA-like
# 6                               Grant   ODA-like
#
#                                       funding_agency       intent  \
# 0  Unspecified Chinese Government Institution, Go...  Development
# 1  Unspecified Chinese Government Institution, Go...  Development
# 2  Unspecified Chinese Government Institution, Go...  Development
# 3  Unspecified Chinese Government Institution, Go...  Development
# 6  Unspecified Chinese Government Institution, Go...  Development
#
#   location_details  latitude  longitude  place_name  usd_defl_2014  year  \
# 0          unknown  18.08581  -15.97850  Nouakchott            NaN  2010
# 1          unknown  15.15846  -12.18430   Sélibaby            NaN  2010
# 2          unknown  16.61659  -11.40453       Kiffa            NaN  2010
# 3          unknown   0.00000    0.00000  Mauritania            NaN  2010
# 6          unknown  -8.83682   13.23432      Luanda            NaN  2001
#
#                                        project_title recipient_condensed  \
# 0  29th medical team to Mauritania to assist loca...          Mauritania
# 1  29th medical team to Mauritania to assist loca...          Mauritania
# 2  29th medical team to Mauritania to assist loca...          Mauritania
# 3  29th medical team to Mauritania to assist loca...          Mauritania
# 6                      Computers and Sewing Machines              Angola
#
#      round_coded  null_amounts_as_zero  \
# 0  ChinatoAfrica                   0.0
# 1  ChinatoAfrica                   0.0
# 2  ChinatoAfrica                   0.0
# 3  ChinatoAfrica                   0.0
# 6  ChinatoAfrica                   0.0
#
#                                                words
# 0  Unspecified Chinese Government Institution, Go...
# 1  Unspecified Chinese Government Institution, Go...
# 2  Unspecified Chinese Government Institution, Go...
# 3  Unspecified Chinese Government Institution, Go...
# 6  Unspecified Chinese Government Institution, Go...

# %%
# Reseting my index so that the numbers are consecutive 
china_aid_unknown = china_aid_unknown.reset_index(drop=True)

# %%
# Dropping the column of zeros 
china_aid_unknown = china_aid_unknown.drop(columns=['null_amounts_as_zero'])

# %%
# Changing the name of the column to aid amount 
china_aid_known.rename(columns={'null_amounts_as_zero' : 'aid_amount'}, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
# Looking at the info for the known aid 
china_aid_known.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2208 entries, 4 to 3643
# Data columns (total 17 columns):
# all_recipients         2208 non-null object
# crs_sector_name        2208 non-null object
# flow                   2208 non-null object
# flow_class             2208 non-null object
# funding_agency         2208 non-null object
# intent                 2208 non-null object
# location_details       2208 non-null object
# latitude               2208 non-null float64
# longitude              2208 non-null float64
# place_name             2208 non-null object
# usd_defl_2014          2208 non-null float64
# year                   2208 non-null int64
# project_title          2208 non-null object
# recipient_condensed    2208 non-null object
# round_coded            2208 non-null object
# aid_amount             2208 non-null float64
# words                  2208 non-null object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 310.5+ KB

# %%
# Looking at how the aid amounts are distributed 
china_aid_known['aid_amount'].describe()
# Out:
# count    2.208000e+03
# mean     1.764717e+08
# std      3.838847e+08
# min      1.760000e+02
# 25%      4.109015e+06
# 50%      4.100000e+07
# 75%      1.346656e+08
# max      2.846909e+09
# Name: aid_amount, dtype: float64

# %%
# Using my words variable as the X variable and aid_amount as my y (predicted) variable 
X = china_aid_known['words']
y = china_aid_known['aid_amount']

# %%
# Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=22)

# %%
# Setting the pipeline for random forest 
pipe = Pipeline([('tfidf', TfidfVectorizer()),
                     ('rf', RandomForestRegressor())
                ])
# Pipeline parameters
pipe_params = {
    'tfidf__max_features': [10000],
    'tfidf__ngram_range': [(1,1)],
    'tfidf__stop_words' : [stop_words.ENGLISH_STOP_WORDS],
    'rf__n_estimators': [100, 150],
    'rf__max_depth': [None, 5, 6]
}
# Instantiating a grid search
gs = GridSearchCV(pipe, 
                  param_grid=pipe_params) 
# Fitting my model
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True,
#                                                         stop_words=None,
#                                                         strip_...
#                          'tfidf__stop_words': [frozenset({'a', 'about', 'above',
#                                                           'across', 'after',
#                                                           'afterwards', 'again',
#                                                           'against', 'all',
#                                                           'almost', 'alone',
#                                                           'along', 'already',
#                                                           'also', 'although',
#                                                           'always', 'am',
#                                                           'among', 'amongst',
#                                                           'amoungst', 'amount',
#                                                           'an', 'and',
#                                                           'another', 'any',
#                                                           'anyhow', 'anyone',
#                                                           'anything', 'anyway',
#                                                           'anywhere', ...})]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Looking at the best score 
gs.best_score_
# Out:
# 0.9020865757318877

# %%
# Setting the model as the best estimator 
gs_model = gs.best_estimator_

# %%
# Scoring my model on the training data
gs_model.score(X_train, y_train)
# Out:
# 0.9880543812746587

# %%
# Scoring my model on the testing data. The model is a bit overfit. 
gs_model.score(X_test, y_test)
# Out:
# 0.9421663036632847

# %%
# Setting the pipeline for tfidf and extra trees
pipe2 = Pipeline([('tfidf', TfidfVectorizer()),
                     ('xt', ExtraTreesRegressor())
                ])
# Setting the pipeline parameters
pipe_params2 = {
    'tfidf__max_features': [10000],
    'tfidf__ngram_range': [(1,1)],
    'tfidf__stop_words' : [stop_words.ENGLISH_STOP_WORDS],
    'xt__n_estimators': [100, 150],
    'xt__max_depth': [None, 5, 6]
}
# Instantiating the grid search
gs2 = GridSearchCV(pipe2, 
                  param_grid=pipe_params2) 
# Fitting the model
gs2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('tfidf',
#                                         TfidfVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.float64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         norm='l2',
#                                                         preprocessor=None,
#                                                         smooth_idf=True,
#                                                         stop_words=None,
#                                                         strip_...
#                                                           'afterwards', 'again',
#                                                           'against', 'all',
#                                                           'almost', 'alone',
#                                                           'along', 'already',
#                                                           'also', 'although',
#                                                           'always', 'am',
#                                                           'among', 'amongst',
#                                                           'amoungst', 'amount',
#                                                           'an', 'and',
#                                                           'another', 'any',
#                                                           'anyhow', 'anyone',
#                                                           'anything', 'anyway',
#                                                           'anywhere', ...})],
#                          'xt__max_depth': [None, 5, 6],
#                          'xt__n_estimators': [100, 150]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Checking my best score 
gs2.best_score_
# Out:
# 0.9322076754789619

# %%
# Setting the model as the best estimator 
gs_model2 = gs2.best_estimator_

# %%
# Checking the training score 
gs_model2.score(X_train, y_train)
# Out:
# 0.9999999999964637

# %%
# Checking the testing score. It's a bit overfit. 
gs_model2.score(X_test, y_test)
# Out:
# 0.9446223889743852

# %%
# Generating predictions based from the model for the unknown data 
predictions = gs2.predict(china_aid_unknown['words'])

# %%
# Looking at the shape of my predictions
predictions.shape
# Out:
# (1436,)

# %%
# Putting my predicted value into a data frame
china_aid_predicted = pd.DataFrame(predictions, columns=['aid_amount'])

# %%
# Looking at the shape of my data frame
china_aid_predicted.shape
# Out:
# (1436, 1)

# %%
# Checking out my dataframe
china_aid_predicted.head()
# Out:
#      aid_amount
# 0  9.423218e+06
# 1  9.569451e+06
# 2  9.423245e+06
# 3  9.663842e+06
# 4  2.520782e+06

# %%
# Checking the shape of the unknown aid dataframe
china_aid_unknown.shape
# Out:
# (1436, 16)

# %%
# Looking at my dataframe 
china_aid_unknown.head()
# Out:
#   all_recipients               crs_sector_name  \
# 0     Mauritania                        Health
# 1     Mauritania                        Health
# 2     Mauritania                        Health
# 3     Mauritania                        Health
# 4         Angola  Government and Civil Society
#
#                                  flow flow_class  \
# 0  Free-standing technical assistance   ODA-like
# 1  Free-standing technical assistance   ODA-like
# 2  Free-standing technical assistance   ODA-like
# 3  Free-standing technical assistance   ODA-like
# 4                               Grant   ODA-like
#
#                                       funding_agency       intent  \
# 0  Unspecified Chinese Government Institution, Go...  Development
# 1  Unspecified Chinese Government Institution, Go...  Development
# 2  Unspecified Chinese Government Institution, Go...  Development
# 3  Unspecified Chinese Government Institution, Go...  Development
# 4  Unspecified Chinese Government Institution, Go...  Development
#
#   location_details  latitude  longitude  place_name  usd_defl_2014  year  \
# 0          unknown  18.08581  -15.97850  Nouakchott            NaN  2010
# 1          unknown  15.15846  -12.18430   Sélibaby            NaN  2010
# 2          unknown  16.61659  -11.40453       Kiffa            NaN  2010
# 3          unknown   0.00000    0.00000  Mauritania            NaN  2010
# 4          unknown  -8.83682   13.23432      Luanda            NaN  2001
#
#                                        project_title recipient_condensed  \
# 0  29th medical team to Mauritania to assist loca...          Mauritania
# 1  29th medical team to Mauritania to assist loca...          Mauritania
# 2  29th medical team to Mauritania to assist loca...          Mauritania
# 3  29th medical team to Mauritania to assist loca...          Mauritania
# 4                      Computers and Sewing Machines              Angola
#
#      round_coded                                              words
# 0  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 1  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 2  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 3  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 4  ChinatoAfrica  Unspecified Chinese Government Institution, Go...

# %%
# Merging my predictions with my unknown dataframe 
china_aid_modeled = china_aid_unknown.merge(china_aid_predicted, left_index=True, right_index=True)

# %%
# Looking at the shape of the merged data frame 
china_aid_modeled.shape
# Out:
# (1436, 17)

# %%
# Making a column to distinguish the values predicted by modeling
# This way I can exclude the predicted data if I would like
china_aid_modeled['predicted_by_modeling']= True

# %%
# Looking at my modeled data 
china_aid_modeled.head()
# Out:
#   all_recipients               crs_sector_name  \
# 0     Mauritania                        Health
# 1     Mauritania                        Health
# 2     Mauritania                        Health
# 3     Mauritania                        Health
# 4         Angola  Government and Civil Society
#
#                                  flow flow_class  \
# 0  Free-standing technical assistance   ODA-like
# 1  Free-standing technical assistance   ODA-like
# 2  Free-standing technical assistance   ODA-like
# 3  Free-standing technical assistance   ODA-like
# 4                               Grant   ODA-like
#
#                                       funding_agency       intent  \
# 0  Unspecified Chinese Government Institution, Go...  Development
# 1  Unspecified Chinese Government Institution, Go...  Development
# 2  Unspecified Chinese Government Institution, Go...  Development
# 3  Unspecified Chinese Government Institution, Go...  Development
# 4  Unspecified Chinese Government Institution, Go...  Development
#
#   location_details  latitude  longitude  place_name  usd_defl_2014  year  \
# 0          unknown  18.08581  -15.97850  Nouakchott            NaN  2010
# 1          unknown  15.15846  -12.18430   Sélibaby            NaN  2010
# 2          unknown  16.61659  -11.40453       Kiffa            NaN  2010
# 3          unknown   0.00000    0.00000  Mauritania            NaN  2010
# 4          unknown  -8.83682   13.23432      Luanda            NaN  2001
#
#                                        project_title recipient_condensed  \
# 0  29th medical team to Mauritania to assist loca...          Mauritania
# 1  29th medical team to Mauritania to assist loca...          Mauritania
# 2  29th medical team to Mauritania to assist loca...          Mauritania
# 3  29th medical team to Mauritania to assist loca...          Mauritania
# 4                      Computers and Sewing Machines              Angola
#
#      round_coded                                              words  \
# 0  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 1  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 2  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 3  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
# 4  ChinatoAfrica  Unspecified Chinese Government Institution, Go...
#
#      aid_amount  predicted_by_modeling
# 0  9.423218e+06                   True
# 1  9.569451e+06                   True
# 2  9.423245e+06                   True
# 3  9.663842e+06                   True
# 4  2.520782e+06                   True

# %%
# Making a column for the known values 
china_aid_known['predicted_by_modeling']= False
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Looking at my dataframe 
china_aid_known.head()
# Out:
#    all_recipients                           crs_sector_name  \
# 4      Mauritania                     Transport and Storage
# 5          Angola                        Emergency Response
# 10       Botswana  Other Social infrastructure and services
# 11       Botswana  Other Social infrastructure and services
# 12       Botswana  Other Social infrastructure and services
#
#                                   flow flow_class  \
# 4   Loan (excluding debt rescheduling)   ODA-like
# 5                                Grant   ODA-like
# 10  Loan (excluding debt rescheduling)   ODA-like
# 11  Loan (excluding debt rescheduling)   ODA-like
# 12  Loan (excluding debt rescheduling)   ODA-like
#
#                                        funding_agency       intent  \
# 4      Export-Import Bank of China, Government Agency  Development
# 5   Unspecified Chinese Government Institution, Go...  Development
# 10  Unspecified Chinese Government Institution, Go...  Development
# 11  Unspecified Chinese Government Institution, Go...  Development
# 12  Unspecified Chinese Government Institution, Go...  Development
#
#                                      location_details  latitude  longitude  \
# 4                                          Nouakchott  18.08581  -15.97850
# 5                                        Bie Province -12.34989   17.30310
# 10  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -24.60166   24.72810
# 11  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -25.22435   25.67728
# 12  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -24.65451   25.90859
#
#             place_name  usd_defl_2014  year  \
# 4           Nouakchott    396886331.0  2008
# 5   Província do Bié      1364094.0  2001
# 10             Jwaneng     51378371.0  2004
# 11             Lobatse     51378371.0  2004
# 12            Gaborone     51378371.0  2004
#
#                                         project_title recipient_condensed  \
# 4   China issues 2 billion yuan loan to fund Port ...          Mauritania
# 5   China grants $600,000 USD in food aid for floo...              Angola
# 10  China loans 117 million BWP for medium and low...            Botswana
# 11  China loans 117 million BWP for medium and low...            Botswana
# 12  China loans 117 million BWP for medium and low...            Botswana
#
#       round_coded   aid_amount  \
# 4   ChinatoAfrica  396886331.0
# 5   ChinatoAfrica    1364094.0
# 10  ChinatoAfrica   51378371.0
# 11  ChinatoAfrica   51378371.0
# 12  ChinatoAfrica   51378371.0
#
#                                                 words  predicted_by_modeling
# 4   Export-Import Bank of China, Government Agency...                  False
# 5   Unspecified Chinese Government Institution, Go...                  False
# 10  Unspecified Chinese Government Institution, Go...                  False
# 11  Unspecified Chinese Government Institution, Go...                  False
# 12  Unspecified Chinese Government Institution, Go...                  False

# %%
# Dropping the columns for words and usd_defl_2014 (since the latter is a repeat)
china_aid_known = china_aid_known.drop(columns=['words', 'usd_defl_2014'])

# %%
# Setting the columns to be the same order as the known data for appending them
china_aid_modeled = china_aid_modeled[['all_recipients', 'crs_sector_name', 'flow', 'flow_class', 'funding_agency', 'intent', 'location_details', 'latitude', 'longitude', 'place_name', 'year', 'project_title', 'recipient_condensed', 'round_coded', 'aid_amount', 'predicted_by_modeling']]

# %%
# Appending the two data frames 
china_aid_all = china_aid_known.append([china_aid_modeled])

# %%
# Looking at the combined new data frame
china_aid_all.head()
# Out:
#    all_recipients                           crs_sector_name  \
# 4      Mauritania                     Transport and Storage
# 5          Angola                        Emergency Response
# 10       Botswana  Other Social infrastructure and services
# 11       Botswana  Other Social infrastructure and services
# 12       Botswana  Other Social infrastructure and services
#
#                                   flow flow_class  \
# 4   Loan (excluding debt rescheduling)   ODA-like
# 5                                Grant   ODA-like
# 10  Loan (excluding debt rescheduling)   ODA-like
# 11  Loan (excluding debt rescheduling)   ODA-like
# 12  Loan (excluding debt rescheduling)   ODA-like
#
#                                        funding_agency       intent  \
# 4      Export-Import Bank of China, Government Agency  Development
# 5   Unspecified Chinese Government Institution, Go...  Development
# 10  Unspecified Chinese Government Institution, Go...  Development
# 11  Unspecified Chinese Government Institution, Go...  Development
# 12  Unspecified Chinese Government Institution, Go...  Development
#
#                                      location_details  latitude  longitude  \
# 4                                          Nouakchott  18.08581  -15.97850
# 5                                        Bie Province -12.34989   17.30310
# 10  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -24.60166   24.72810
# 11  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -25.22435   25.67728
# 12  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -24.65451   25.90859
#
#             place_name  year  \
# 4           Nouakchott  2008
# 5   Província do Bié  2001
# 10             Jwaneng  2004
# 11             Lobatse  2004
# 12            Gaborone  2004
#
#                                         project_title recipient_condensed  \
# 4   China issues 2 billion yuan loan to fund Port ...          Mauritania
# 5   China grants $600,000 USD in food aid for floo...              Angola
# 10  China loans 117 million BWP for medium and low...            Botswana
# 11  China loans 117 million BWP for medium and low...            Botswana
# 12  China loans 117 million BWP for medium and low...            Botswana
#
#       round_coded   aid_amount  predicted_by_modeling
# 4   ChinatoAfrica  396886331.0                  False
# 5   ChinatoAfrica    1364094.0                  False
# 10  ChinatoAfrica   51378371.0                  False
# 11  ChinatoAfrica   51378371.0                  False
# 12  ChinatoAfrica   51378371.0                  False

# %%
# Looking for null values and data types. Everything seems good
china_aid_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3644 entries, 4 to 1435
# Data columns (total 16 columns):
# all_recipients           3644 non-null object
# crs_sector_name          3644 non-null object
# flow                     3644 non-null object
# flow_class               3644 non-null object
# funding_agency           3644 non-null object
# intent                   3644 non-null object
# location_details         3644 non-null object
# latitude                 3644 non-null float64
# longitude                3644 non-null float64
# place_name               3644 non-null object
# year                     3644 non-null int64
# project_title            3644 non-null object
# recipient_condensed      3644 non-null object
# round_coded              3644 non-null object
# aid_amount               3644 non-null float64
# predicted_by_modeling    3644 non-null bool
# dtypes: bool(1), float64(3), int64(1), object(11)
# memory usage: 459.1+ KB

# %%
# Making a column for aid in millions to use in Tableau 
china_aid_all['aid_in_millions'] = china_aid_all['aid_amount'].div(1000000)

# %%
# Looking to see the new column 
china_aid_all.head()
# Out:
#    all_recipients                           crs_sector_name  \
# 4      Mauritania                     Transport and Storage
# 5          Angola                        Emergency Response
# 10       Botswana  Other Social infrastructure and services
# 11       Botswana  Other Social infrastructure and services
# 12       Botswana  Other Social infrastructure and services
#
#                                   flow flow_class  \
# 4   Loan (excluding debt rescheduling)   ODA-like
# 5                                Grant   ODA-like
# 10  Loan (excluding debt rescheduling)   ODA-like
# 11  Loan (excluding debt rescheduling)   ODA-like
# 12  Loan (excluding debt rescheduling)   ODA-like
#
#                                        funding_agency       intent  \
# 4      Export-Import Bank of China, Government Agency  Development
# 5   Unspecified Chinese Government Institution, Go...  Development
# 10  Unspecified Chinese Government Institution, Go...  Development
# 11  Unspecified Chinese Government Institution, Go...  Development
# 12  Unspecified Chinese Government Institution, Go...  Development
#
#                                      location_details  latitude  longitude  \
# 4                                          Nouakchott  18.08581  -15.97850
# 5                                        Bie Province -12.34989   17.30310
# 10  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -24.60166   24.72810
# 11  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -25.22435   25.67728
# 12  Maun, Jwaneng, Gaborone, Lobatse, Francistown ... -24.65451   25.90859
#
#             place_name  year  \
# 4           Nouakchott  2008
# 5   Província do Bié  2001
# 10             Jwaneng  2004
# 11             Lobatse  2004
# 12            Gaborone  2004
#
#                                         project_title recipient_condensed  \
# 4   China issues 2 billion yuan loan to fund Port ...          Mauritania
# 5   China grants $600,000 USD in food aid for floo...              Angola
# 10  China loans 117 million BWP for medium and low...            Botswana
# 11  China loans 117 million BWP for medium and low...            Botswana
# 12  China loans 117 million BWP for medium and low...            Botswana
#
#       round_coded   aid_amount  predicted_by_modeling  aid_in_millions
# 4   ChinatoAfrica  396886331.0                  False       396.886331
# 5   ChinatoAfrica    1364094.0                  False         1.364094
# 10  ChinatoAfrica   51378371.0                  False        51.378371
# 11  ChinatoAfrica   51378371.0                  False        51.378371
# 12  ChinatoAfrica   51378371.0                  False        51.378371

# %%
# Saving my dataframe to a csv 
china_aid_all.to_csv('./aid_data/aid_data_wm/chinese_aid_modeled.csv', index=False)

# %% [markdown]
# ### Conclusion:
#
# This modeling seemed to be fairly successful, with a 94% accuracy rating. However, I would take this with a grain of salt, because it's possible that there could be differences between the seen and unseen data that could make the model less accurate on the unseen data. However, given the lack of transparent information about Chinese aid, using modeling like this could be a good tool to get an approximate idea of the extent of Chinese aid, even if it is a bit less accurate that the 94%.
